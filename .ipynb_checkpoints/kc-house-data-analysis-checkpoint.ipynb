# %%
import pandas as pd

# %%
df = pd.read_csv('kc_house_data.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# ### Age of the house the moment it was sold Vs it price

# %%
[df['date'].min(),df['date'].max()]
# Out:
# ['20140502T000000', '20150527T000000']

# %%
df_ = df[df['yr_renovated']==0][['id','yr_built','date','price','yr_renovated']].copy()

def get_age(end_year, start_year):
    if start_year ==0:
        return 'n/a'
    return end_year - start_year


df_['age (sold - built)'] = df_.apply(lambda row: get_age(
    pd.to_datetime(row['date']).year, row['yr_built']), axis=1)

df_['age (sold - renovation)'] = df_.apply(lambda row: get_age(
    pd.to_datetime(row['date']).year, row['yr_renovated']), axis=1)

df_.sort_values('age (sold - built)').head(10)
# Out:
#                id  yr_built             date     price  yr_renovated  \
# 17098  9126100346      2015  20140617T000000  350000.0             0
# 20963  6058600220      2015  20140731T000000  230000.0             0
# 2687   3076500830      2015  20141029T000000  385195.0             0
# 20852  1257201420      2015  20140709T000000  595000.0             0
# 14489  2770601530      2015  20140826T000000  500000.0             0
# 21372  6169901185      2015  20140520T000000  490000.0             0
# 7526   9520900210      2015  20141231T000000  614285.0             0
# 8039   1250200495      2015  20140624T000000  455000.0             0
# 19805  9126100765      2015  20140801T000000  455000.0             0
# 20770  9310300160      2015  20140828T000000  357000.0             0
#
#        age (sold - built) age (sold - renovation)
# 17098                  -1                     n/a
# 20963                  -1                     n/a
# 2687                   -1                     n/a
# ...

# %%
# NEW !!
pd.set_option('display.max_rows',100)

df_[['id','yr_built','date','age (sold - built)','yr_renovated','age (sold - renovation)','price']].sort_values(by=['yr_built','date']).head(100)
# Out:
#                id  yr_built             date  age (sold - built)  \
# 15050  4003000285      1900  20140504T000000                 114
# 5928   1972201856      1900  20140507T000000                 114
# 1780   2264500890      1900  20140508T000000                 114
# 8900    917000300      1900  20140520T000000                 114
# 2551   3797000830      1900  20140530T000000                 114
# 17182  7883601155      1900  20140530T000000                 114
# 1467   7935000125      1900  20140605T000000                 114
# 4697   9126101645      1900  20140610T000000                 114
# 18075  5457800930      1900  20140613T000000                 114
# 11139  7942602080      1900  20140616T000000                 114
# 11534  3365900520      1900  20140618T000000                 114
# 2961   1947300115      1900  20140619T000000                 114
# 8831   3885804225      1900  20140624T000000                 114
# ...

# %% [raw]
# The above data frame displays the house information and age when sold in ascending order of the age value. It's interesting to notice that part of these houses have negative age due to the fact that sold date is less than the year built of the house.

# %%
df_[df_['age (sold - built)']<0]
# Out:
#                id  yr_built             date     price  yr_renovated  \
# 1763   1832100030      2015  20140625T000000  597326.0             0
# 2687   3076500830      2015  20141029T000000  385195.0             0
# 7526   9520900210      2015  20141231T000000  614285.0             0
# 8039   1250200495      2015  20140624T000000  455000.0             0
# 14489  2770601530      2015  20140826T000000  500000.0             0
# 17098  9126100346      2015  20140617T000000  350000.0             0
# 19805  9126100765      2015  20140801T000000  455000.0             0
# 20770  9310300160      2015  20140828T000000  357000.0             0
# 20852  1257201420      2015  20140709T000000  595000.0             0
# 20963  6058600220      2015  20140731T000000  230000.0             0
# 21262  5694500840      2015  20141125T000000  559000.0             0
# 21372  6169901185      2015  20140520T000000  490000.0             0
#
#        age (sold - built) age (sold - renovation)
# ...

# %% [raw]
# To delve further into the reasons behind those negative ages, the above data frame selects all of the entries with negative age. All of these are equal to -1; these houses were sold after May 2014, which is somewhat close to 2015. Most probably, these houses were still in the early construction phase when they were sold in 2014. It was then confirmed in 2015 that the construction of the houses was complete, hence the yr_built is equal to 2015

# %%
df_['age (sold - built)'].value_counts()
# Out:
# age (sold - built)
#  9      473
#  8      443
#  11     432
#  0      430
#  10     428
#        ...
#  113     27
#  115     21
#  81      16
#  80      12
# -1       12
# Name: count, Length: 117, dtype: int64

# %%
df_['age (sold - built)'] = df_.apply(lambda row: 0 if row['age (sold - built)']<0 else row['age (sold - built)'],axis=1)

df_['age (sold - built)']
# Out:
# 0        59
# 2        82
# 3        49
# 4        28
# 5        13
#          ..
# 21608     5
# 21609     1
# 21610     5
# 21611    11
# 21612     6
# Name: age (sold - built), Length: 20699, dtype: int64

# %%
df_ages_intervals = pd.cut(df_['age (sold - built)'],bins=10)
df_ages_intervals.value_counts()
# Out:
# age (sold - built)
# (-0.115, 11.5]    3888
# (34.5, 46.0]      2826
# (11.5, 23.0]      2724
# (46.0, 57.5]      2716
# (23.0, 34.5]      2552
# (57.5, 69.0]      2453
# (80.5, 92.0]      1079
# (69.0, 80.5]      1048
# (92.0, 103.5]      734
# (103.5, 115.0]     679
# Name: count, dtype: int64

# %%
df_agg = df_.groupby(df_ages_intervals)[['price']].agg(['min','mean','max'])
df_agg
# Out:
#                        price
#                          min           mean        max
# age (sold - built)
# (-0.115, 11.5]      155000.0  608240.557356  5350000.0
# (11.5, 23.0]        154000.0  608206.377386  6890000.0
# (23.0, 34.5]        115000.0  531732.727665  5300000.0
# (34.5, 46.0]         89000.0  474720.119958  3800000.0
# (46.0, 57.5]         75000.0  447525.569588  3070000.0
# (57.5, 69.0]         82000.0  457169.313086  3400000.0
# (69.0, 80.5]         78000.0  446264.874046  3650000.0
# (80.5, 92.0]        105500.0  595739.866543  3000000.0
# (92.0, 103.5]        80000.0  542975.354223  2500000.0
# (103.5, 115.0]       90000.0  609218.365243  3300000.0
